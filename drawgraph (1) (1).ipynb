# %%
import pandas as pd
import matplotlib.pyplot as plt
import json
plt.rcParams.update({'font.size': 10})

# %%
fig, ax = plt.subplots(4, 3, figsize=(18,25))
axdict = {'ax1':ax[0,0],'ax2':ax[0,1],'ax3':ax[0,2],
          'ax4':ax[1,0],'ax5':ax[1,1],'ax6':ax[1,2],
          'ax7':ax[2,0],'ax8':ax[2,1],'ax9':ax[2,2],
          'ax10':ax[3,0],'ax11':ax[3,1],'ax12':ax[3,2]}

marker ={'thirdmethod':'o','fourthmethod':'^','fifthmethod':'*','randomforest':'s','xgboost':'x'}
linestyle = {'thirdmethod': (0, (1, 10)),'fourthmethod':'dotted','fifthmethod':'dashed'}
# BPIC2012

label = 'Label 0'
label1='Label 1'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+1)]
    
    for method in ['thirdmethod','fourthmethod', 'fifthmethod']:
        scoregraph = []
        for prefix in range(5,41, 5):
            with open(r'C:/Users/Dias/Desktop/data/dataset/bpic2012/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
            savedir = r'C:\Users\Dias\Desktop\data\dataset\bpic2012\RIPPER\prefix'+str(prefix)+''
            df_final=pd.read_csv(savedir +'/BPICinput_preprocessed.csv')
            l1=len(df_final[df_final['Label_1']==1])
            l0=len(df_final[df_final['Label_0']==1])
            
            scoregraph.append(resultdict[label][score][0]*l0/(l1+l0)+resultdict[label1][score][0]*l1/(l1+l0))
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(5, 41, 5)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)

    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(5,41, 5):
            with open(r'C:/Users/Dias/Desktop/data/dataset/bpic2012/prefix/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
            savedir = r'C:\Users\Dias\Desktop\data\dataset\bpic2012\RIPPER\prefix'+str(prefix)+''
            df_final=pd.read_csv(savedir +'/BPICinput_preprocessed.csv')
            l1=len(df_final[df_final['Label_1']==1])
            l0=len(df_final[df_final['Label_0']==1])

            scoregraph.append(resultdict[label][score][0]*l0/(l1+l0)+resultdict[label1][score][0]*l1/(l1+l0))
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(5,41, 5)
        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)

    ax.set_ylim(0.2,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length',fontsize=18)

# BPIC_2015_1
label = 'Label 0'
label1='Label 1'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+4)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(5,41,5):
            with open(r'C:/Users/Dias/Desktop/data/dataset/bpic2015_1/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
            savedir = r'C:\Users\Dias\Desktop\data\dataset\bpic2015_1\RIPPER\prefix'+str(prefix)+''
            df_final=pd.read_csv(savedir +'/BPICinput_preprocessed.csv')
            l1=len(df_final[df_final['Label_1']==1])
            l0=len(df_final[df_final['Label_0']==1])

            scoregraph.append(resultdict[label][score][0]*l0/(l1+l0)+resultdict[label1][score][0]*l1/(l1+l0))
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(5,41,5)
        
        legenddict[plabel] = scoregraph
        
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)

    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(5,41,5):
            with open(r'C:/Users/Dias/Desktop/data/dataset/bpic2015_1/prefix/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
            

            savedir = r'C:\Users\Dias\Desktop\data\dataset\bpic2015_1\RIPPER\prefix'+str(prefix)+''
            df_final=pd.read_csv(savedir +'/BPICinput_preprocessed.csv')
            l1=len(df_final[df_final['Label_1']==1])
            l0=len(df_final[df_final['Label_0']==1])

            scoregraph.append(resultdict[label][score][0]*l0/(l1+l0)+resultdict[label1][score][0]*l1/(l1+l0))
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(5,41,5)
        
        legenddict[plabel] = scoregraph
        
        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)

    ax.set_ylim(0,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length',fontsize=18)
    
#BPIC2015_2
label = 'Label 0'
label1='Label 1'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+7)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(5,41,5):
            with open(r'C:/Users/Dias/Desktop/data/dataset/bpic2015_2/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
            savedir = r'C:\Users\Dias\Desktop\data\dataset\bpic2015_2\RIPPER\prefix'+str(prefix)+''
            df_final=pd.read_csv(savedir +'/BPICinput_preprocessed.csv')
            l1=len(df_final[df_final['Accepted']==1])
            l0=len(df_final[df_final['Accepted']==0])

            scoregraph.append(resultdict[label][score][0]*l0/(l1+l0)+resultdict[label1][score][0]*l1/(l1+l0))
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(5,41,5)
        
        legenddict[plabel] = scoregraph
        
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)

    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(5,41,5):
            with open(r'C:/Users/Dias/Desktop/data/dataset/bpic2015_2/prefix/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
            

            savedir = r'C:\Users\Dias\Desktop\data\dataset\bpic2015_2\RIPPER\prefix'+str(prefix)+''
            df_final=pd.read_csv(savedir +'/BPICinput_preprocessed.csv')
            l1=len(df_final[df_final['Accepted']==1])
            l0=len(df_final[df_final['Accepted']==0])

            scoregraph.append(resultdict[label][score][0]*l0/(l1+l0)+resultdict[label1][score][0]*l1/(l1+l0))
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(5,41,5)
        
        legenddict[plabel] = scoregraph
        
        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)

    ax.set_ylim(0,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length',fontsize=18)

#BPIC2015_3
label = 'Label 0'
label1='Label 1'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+10)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(5,41,5):
            with open(r'C:/Users/Dias/Desktop/data/dataset/bpic2015_3/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
            savedir = r'C:\Users\Dias\Desktop\data\dataset\bpic2015_3\RIPPER\prefix'+str(prefix)+''
            df_final=pd.read_csv(savedir +'/BPICinput_preprocessed.csv')
            l1=len(df_final[df_final['Label_1']==1])
            l0=len(df_final[df_final['Label_0']==1])

            scoregraph.append(resultdict[label][score][0]*l0/(l1+l0)+resultdict[label1][score][0]*l1/(l1+l0))
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(5,41,5)
        
        legenddict[plabel] = scoregraph
        
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)

    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(5,41,5):
            with open(r'C:/Users/Dias/Desktop/data/dataset/bpic2015_3/prefix/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
            

            savedir = r'C:\Users\Dias\Desktop\data\dataset\bpic2015_3\RIPPER\prefix'+str(prefix)+''
            df_final=pd.read_csv(savedir +'/BPICinput_preprocessed.csv')
            l1=len(df_final[df_final['Label_1']==1])
            l0=len(df_final[df_final['Label_0']==1])

            scoregraph.append(resultdict[label][score][0]*l0/(l1+l0)+resultdict[label1][score][0]*l1/(l1+l0))
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(5,41,5)
        
        legenddict[plabel] = scoregraph
        
        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)

    ax.set_ylim(0,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length',fontsize=18)
plt.subplots_adjust(bottom=0.05,hspace=0.4)
fig.legend(legenddict.values(),     # The line objects
           labels=legenddict.keys(),   # The labels for each line
           loc="lower center",   # Position of legend
               # Small spacing around legend box
           fontsize=20,
           ncol=5
           )

plt.subplots_adjust(bottom=0.08,hspace=0.4)
fig.legend(legenddict.values(),     # The line objects
           labels=legenddict.keys(),   # The labels for each line
           loc="lower center",   # Position of legend
               # Small spacing around legend box
           fontsize=20,
           ncol=5
           )

plt.text(-16.5,5.25,'Precision',fontsize=20)
plt.text(-5.5,5.25,'Recall',fontsize=20)
plt.text(5,5.25,'F1-score',fontsize=20)

plt.text(-7.8,5.4,'BPIC 2012',fontsize=22)
plt.text(-7.8,3.85,'BPIC 2015_1',fontsize=22)
plt.text(-7.8,2.45,'BPIC 2015_2',fontsize=22)
plt.text(-7.8,1.05,'BPIC 2015_3',fontsize=22)


plt.savefig('./arm_ml2.pdf',bbox_inches='tight')
# Out:
# <ipython-input-12-2d3889720c6a>:230: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   fig.legend(legenddict.values(),     # The line objects
# <ipython-input-12-2d3889720c6a>:239: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   fig.legend(legenddict.values(),     # The line objects
